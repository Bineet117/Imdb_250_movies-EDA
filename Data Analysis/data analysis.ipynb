# %% [markdown]
# ## Importing the Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ___

# %% [markdown]
# ## Reading CSV file

# %%
df = pd.read_csv("Movies_data.csv")
df
# Out:
#      Sno.                                          Movie  Year      Genre  \
# 0       1                       The Shawshank Redemption  1994      Drama
# 1       2                                  The Godfather  1972      Crime
# 2       3                                The Dark Knight  2008     Action
# 3       4                               Schindler's List  1993  Biography
# 4       5  The Lord of the Rings: The Return of the King  2003     Action
# ..    ...                                            ...   ...        ...
# 245   246                             Dances with Wolves  1990  Adventure
# 246   247                                The Incredibles  2004  Animation
# 247   248                                  Groundhog Day  1993     Comedy
# 248   249                                        Aladdin  1992  Animation
# 249   250                                  Life of Brian  1979     Comedy
#
#      Rating  Time  Metascore              Director
# ...

# %%
# Setting "Sno." as index
df.set_index("Sno." , inplace = True)

# %%
df
# Out:
#                                               Movie  Year      Genre  Rating  \
# Sno.
# 1                          The Shawshank Redemption  1994      Drama     9.3
# 2                                     The Godfather  1972      Crime     9.2
# 3                                   The Dark Knight  2008     Action     9.0
# 4                                  Schindler's List  1993  Biography     9.0
# 5     The Lord of the Rings: The Return of the King  2003     Action     9.0
# ...                                             ...   ...        ...     ...
# 246                              Dances with Wolves  1990  Adventure     8.0
# 247                                 The Incredibles  2004  Animation     8.0
# 248                                   Groundhog Day  1993     Comedy     8.0
# 249                                         Aladdin  1992  Animation     8.0
# 250                                   Life of Brian  1979     Comedy     8.0
#
# ...

# %%
# Shape of the dataframe
df.shape
# Out:
# (250, 7)

# %% [markdown]
# ##### It contains 250 Rows & 7 Columns

# %% [markdown]
# ___

# %% [markdown]
# ## Data Exploration

# %%
# First five rows of data
df.head()
# Out:
#                                               Movie  Year      Genre  Rating  \
# Sno.
# 1                          The Shawshank Redemption  1994      Drama     9.3
# 2                                     The Godfather  1972      Crime     9.2
# 3                                   The Dark Knight  2008     Action     9.0
# 4                                  Schindler's List  1993  Biography     9.0
# 5     The Lord of the Rings: The Return of the King  2003     Action     9.0
#
#       Time  Metascore              Director
# Sno.
# 1      142       82.0        Frank Darabont
# 2      175      100.0  Francis Ford Coppola
# 3      152       84.0     Christopher Nolan
# 4      195       95.0      Steven Spielberg
# 5      201       94.0         Peter Jackson

# %%
# Last five rows of data
df.tail()
# Out:
#                    Movie  Year      Genre  Rating  Time  Metascore  \
# Sno.
# 246   Dances with Wolves  1990  Adventure     8.0   181       72.0
# 247      The Incredibles  2004  Animation     8.0   115       90.0
# 248        Groundhog Day  1993     Comedy     8.0   101       72.0
# 249              Aladdin  1992  Animation     8.0    90       86.0
# 250        Life of Brian  1979     Comedy     8.0    94       77.0
#
#             Director
# Sno.
# 246    Kevin Costner
# 247        Brad Bird
# 248     Harold Ramis
# 249   Ron Clements,
# 250      Terry Jones

# %%
# Check datatypes of each columns
df.dtypes
# Out:
# Movie         object
# Year           int64
# Genre         object
# Rating       float64
# Time           int64
# Metascore    float64
# Director      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 1 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Movie      250 non-null    object
#  1   Year       250 non-null    int64
#  2   Genre      250 non-null    object
#  3   Rating     250 non-null    float64
#  4   Time       250 non-null    int64
#  5   Metascore  233 non-null    float64
#  6   Director   250 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 15.6+ KB

# %%
# Describing numerical columns 
df.describe()
# Out:
#               Year      Rating       Time   Metascore
# count   250.000000  250.000000  250.00000  233.000000
# mean   1986.716000    8.306400  129.07600   82.742489
# std      25.324785    0.232757   29.85141   10.969108
# min    1921.000000    8.000000   45.00000   55.000000
# 25%    1966.250000    8.100000  107.25000   75.000000
# 50%    1994.000000    8.200000  126.50000   85.000000
# 75%    2007.000000    8.400000  145.75000   91.000000
# max    2023.000000    9.300000  238.00000  100.000000

# %%
# Check for null values
df.isnull().sum()
# Out:
# Movie         0
# Year          0
# Genre         0
# Rating        0
# Time          0
# Metascore    17
# Director      0
# dtype: int64

# %% [markdown]
# Metascore has 17 missing values

# %%
# Heatmap 
sns.heatmap(df.corr() , annot = True)
# Out:
# C:\Users\91620\AppData\Local\Temp\ipykernel_15900\2481183503.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr() , annot = True)
# <Axes: >

# %% [markdown]
# ___

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### 1. Movies of each category

# %%
# plt.figure(figsize=(7, 4))
ax = sns.countplot(x = "Genre" , data = df)

for bars in ax.containers:
    ax.bar_label(bars)

plt.ylabel('No. of Movies')
plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# From the above graph we can say that most of the movies are of `drama` category

# %% [markdown]
# ### 2. Top 5 director whose movies has crossed a metascore of 85

# %%
df[df["Metascore"] > 85]["Director"].value_counts().head()
# Out:
# Akira Kurosawa      6
# Alfred Hitchcock    5
# Charles Chaplin     4
# Steven Spielberg    4
# Billy Wilder        4
# Name: Director, dtype: int64

# %% [markdown]
# ### 3. Top 5 director whose movies has crossed a rating of 8.0

# %%
df[df["Rating"] > 8.0]["Director"].value_counts().head()

# plt.bar(["Christopher Nolan","Steven Spielberg","Stanley Kubrick","Martin Scorsese","Alfred Hitchcock"],df[df["Rating"] > 8.0]["Director"].value_counts().head() )
# plt.xticks(rotation = 45)
# Out:
# Christopher Nolan    8
# Martin Scorsese      7
# Steven Spielberg     7
# Stanley Kubrick      7
# Alfred Hitchcock     6
# Name: Director, dtype: int64

# %% [markdown]
# ### 4. Which decade has most movies

# %%
plt.figure(figsize = (5,3))
sns.histplot(df["Year"]  , kde = True )
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# from the above graph (2000-2010) has most no. of movies

# %% [markdown]
# ### 5. Top 5 movies category whose rating is more than 8.5

# %%
df[df["Rating"] > 8.5]["Genre"].value_counts().head(5)
# Out:
# Action       11
# Crime         9
# Drama         6
# Biography     2
# Adventure     2
# Name: Genre, dtype: int64

# %% [markdown]
# ### 6. Top 5 oldest movies

# %%
for i in df.sort_values(by = "Year" ).head()["Movie"].values:
    print(i)
# Out:
# The Kid
# Sherlock Jr.
# The Gold Rush
# The General
# Metropolis

# %% [markdown]
# ### 7. Runtime Analysis
# There is a column named `Runtime` in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Plot a `histogram` or `distplot` of seaborn to find the Runtime range most of the movies fall into.

# %%
plt.figure(figsize = [5,3])
runtime=sns.histplot(data = df , x = df["Time"] , kde = True )

plt.ylabel('No. of Movies')
# Out:
# Text(0, 0.5, 'No. of Movies')

# %% [markdown]
# Most of the movies appear to be sharply 2 hour-long.

# %% [markdown]
# ### 8. Movie Release Years by Genre: A Boxplot Visualization

# %%
sns.boxplot(x= "Genre",  y = "Year" , data = df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 9. Number of movies by each director

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x  = "Director" , data = df)

plt.xlabel('Director',fontsize=30)
plt.ylabel('No. of movies',fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# most of the director has 1 movie

# %% [markdown]
# ### 10. Ratio of each categories in `Genre`

# %%
# df["Genre"].value_counts(normalize = True)
plt.figure(figsize = (4,4))
num = df["Genre"].value_counts().head(9)
plt.pie(num , autopct = "%.2f",labels =num.index )
plt.show()
